# %%
import numpy as np

import matplotlib.pyplot as plt

import workflow as wf

# %%
def load_data(filename):
    
    datapath = "Data/"

    X_A = np.load(datapath + filename + "-X_A" + ".npy")
    X_B = np.load(datapath + filename + "-X_B" + ".npy")
    
    return X_A, X_B

# %%
X_A, X_B = load_data("sim_2")

# %%
def plot_movie(filename, vmin=None, vmax=None):
    X_A, X_B = load_data(filename)

# %%
for t in np.arange(0, 1_500_000, 50_000):
    plt.imshow(X_A[t], vmin=, vmax=i+25)
    plt.show()

# %%
for i in np.arange(0, 1000, 25):
    plt.imshow(X_A[-1], vmin=i, vmax=i+25)
    plt.show()

# %%
X_A[-1].max()
# Out:
# 906

# %%
i = 2
f'{i}.png'
# Out:
# '2.png'

# %%
def make_gif():
    # build gif
    with imageio.get_writer('mygif.gif', mode='I') as writer:
        for filename in filenames:
            image = imageio.imread(filename)
            writer.append_data(image)

# %%
# suffix should be time and X_A or X_B.

# %%
def plot_3d(M, filename, suffix, save=True, zlim=None, dpi=300):
    
    picturepath = "Pictures"
    params = wf.get_params(filename)


    m, n = params['m'], params['n']

    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

    # Make data
    X, Y = np.meshgrid(np.arange(100), np.arange(100))
    Z = M


    # Plot the surface
    surf = ax.plot_surface(X, Y, Z, cmap='viridis',
                           linewidth=0)

    if zlim:
        ax.set_zlim(100, 300)

    # Remove tick labels on x and y
    ax.set_xticklabels([])
    ax.set_yticklabels([])


    # ax.view_init(30, -60)


    # Add a color bar which maps values to colors
    fig.colorbar(surf, shrink=0.5, aspect=5)

    if save:
        plt.tight_layout()
        plt.savefig(picturepath + filename + suffix + ".png", dpi=dpi)

# %%
X_A[-1]
# Out:
# array([[195, 200, 189, ..., 189, 194, 182],
#        [193, 204, 198, ..., 172, 202, 195],
#        [220, 184, 203, ..., 200, 215, 216],
#        ...,
#        [193, 212, 224, ..., 223, 218, 211],
#        [187, 201, 193, ..., 224, 207, 216],
#        [169, 188, 202, ..., 202, 193, 194]], dtype=int16)

# %%
plt.imshow(X_A[-1])
plt.colorbar()
plt.show()

# %%
plt.imshow(X_B[-1]);

# %%
X_A
# Out:
# array([[[200, 200, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200],
#         ...,
#         [200, 200, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200]],
#
#        [[200, 200, 200, ..., 200, 200, 200],
#         [201, 199, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200],
#         ...,
#         [201, 199, 201, ..., 200, 199, 201],
#         [200, 200, 200, ..., 200, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200]],
#
#        [[200, 200, 201, ..., 200, 200, 200],
#         [201, 199, 200, ..., 199, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200],
#         ...,
#         [201, 199, 201, ..., 199, 199, 202],
#         [200, 200, 200, ..., 201, 200, 200],
#         [200, 200, 200, ..., 200, 200, 200]],
#
#        ...,
#
#        [[196, 199, 189, ..., 189, 194, 182],
# ...

# %%
short_run = "smaller-spots-short-21_11_25_1550"

# %%
datapath = "Data/"

X_A = np.load(datapath + short_run + "-X_A" + ".npy")

# %%
X_B = np.load(datapath + short_run + "-X_B" + ".npy")

# %%
plt.imshow(X_A[-1]);

# %%
X_A[-1]
# Out:
# array([[181, 216, 185, ..., 149, 138, 140],
#        [169, 189, 213, ..., 157, 177, 191],
#        [170, 193, 179, ..., 242, 284, 315],
#        ...,
#        [229, 238, 208, ..., 182, 137, 140],
#        [323, 357, 295, ..., 190, 161, 165],
#        [366, 414, 235, ..., 228, 232, 153]], dtype=int16)

# %%
X_B[-1]
# Out:
# array([[181, 216, 185, ..., 149, 138, 140],
#        [169, 189, 213, ..., 157, 177, 191],
#        [170, 193, 179, ..., 242, 284, 315],
#        ...,
#        [229, 238, 208, ..., 182, 137, 140],
#        [323, 357, 295, ..., 190, 161, 165],
#        [366, 414, 235, ..., 228, 232, 153]], dtype=int16)

# %%
plt.imshow(X_B[-1]);
